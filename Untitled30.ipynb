# %%
#A1
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset from the CSV file
df = pd.read_csv('mldatasetfinal numbers.csv')

# Select two numeric columns from the dataset for the scatter plot
feature1 = df['Mileage']
feature2 = df['Engine Capacity']

# Plotting the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(feature1, feature2, color='b', alpha=0.5)
plt.title('Scatter Plot of Two Features')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True)
plt.show()

# %%
#A2
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error


df = pd.read_csv('mldatasetfinal numbers.csv')


X = df['Mileage'].values.reshape(-1, 1)  
y = df['Price'].values  


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)


model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)


mse = mean_squared_error(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 6787675230948.941

# %%
#A3
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
data = pd.read_csv('mldatasetfinal numbers.csv')
X = data['Mileage'].values.reshape(-1, 1)
y = data['Price'].values
model = LinearRegression()
model.fit(X, y)
coefficients = model.coef_
intercept = model.intercept_
y_pred = model.predict(X)
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)
print(f"Coefficients: {coefficients}")
print(f"Intercept: {intercept}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Coefficients: [-8.04725056]
# Intercept: 2814860.989491233
# Mean Squared Error: 7730914734256.165
# R-squared: 0.03595976167551207

# %%
#A4
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
data = pd.read_csv('mldatasetfinal numbers.csv')
threshold = 2000000 
data['PriceClass'] = data['Price'] > threshold
X = data[['Mileage']]
y = data['PriceClass']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
logistic_regression = LogisticRegression()
logistic_regression.fit(X_train, y_train)
y_pred = logistic_regression.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy on the test set: {accuracy:.2f}')
# Out:
# Accuracy on the test set: 0.67

# %%
#A5
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# Load the dataset from the CSV file
data = pd.read_csv('mldatasetfinal numbers.csv')

# Assuming 'X' contains the features and 'y' contains the target variable
X = data[['Cylinders', 'Airbags','Color','Mileage']]  # Features
y = data['Price']  # Target variable

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Train a Regression Tree model
reg_tree_model = DecisionTreeRegressor()
reg_tree_model.fit(X_train, y_train)

# Train a k-NN Regressor model
knn_model = KNeighborsRegressor()
knn_model.fit(X_train, y_train)

# Use the models to make predictions on the test set
y_pred_reg_tree = reg_tree_model.predict(X_test)
y_pred_knn = knn_model.predict(X_test)

# Calculate the mean squared error for both models
mse_reg_tree = mean_squared_error(y_test, y_pred_reg_tree)
mse_knn = mean_squared_error(y_test, y_pred_knn)

# Print the mean squared error for both models
print(f"Mean Squared Error for Regression Tree: {mse_reg_tree}")
print(f"Mean Squared Error for k-NN Regressor: {mse_knn}")
# Out:
# Mean Squared Error for Regression Tree: 11585057513622.803
# Mean Squared Error for k-NN Regressor: 8029742498523.908
